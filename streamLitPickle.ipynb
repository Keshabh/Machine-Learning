# %%
# !pip install streamlit
#lets deploy it using streamlit

# %%
#lets unpickle the savedModel
import pickle
import numpy as np
import pandas as pd
import streamlit as st

# %%
model = pickle.load(open('/content/Savedmodel.pkl','rb'))
# Out:
# SVC(kernel='linear')

# %%
# data = (0,135,94,46,145,40.6,0.284,26)
# data = np.array(data)
# data = data.reshape(1,-1)
# model.predict(data)[0]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# np.int64(0)

# %%
def diabetes_prediction(data):
  data = np.array(data)
  data = data.reshape(1,-1)
  predicted_val = model.predict(data)
  print(predicted_val)
  if predicted_val[0]==0:
    return "Not diabetic"
  else:
    return "Diabetic"

diabetes_prediction((5,135,94,46,145,50.6,0.284,26))
# Out:
# [1]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 'Diabetic'

# %%
def main():
  st.title("Diabetes prediction web app")
  Pregnancies = st.text_input("Number of Pregnancies")
  Glucose = st.text_input("Glucose Level")
  BloodPressure = st.text_input("Blood Pressure Value")
  SkinThickness = st.text_input("Skin Thickness Value")
  Insulin = st.text_input("Insulin Level")
  BMI = st.text_input("BMI Value")
  DiabetesPedigreeFunction = st.text_input("Diabetes Pedigree Function value")
  Age = st.text_input("Age of person")

  #code for prediction
  diagnosis = ''
  if st.button("Diabetes Test Result"):
    diagnosis = diabetes_prediction([Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age])

  st.success(diagnosis)

# %%
if __name__ == '__main__':
  main()
# Out:
# 2025-08-01 23:45:31.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-01 23:45:31.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
#command to run in prompt
#streamlit run "fileName.py"
